# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# # Data acquisition - politician wikipedia data

# %%
# These are standard python modules
import json, time, urllib.parse
#
# The 'requests' module is not a standard Python module. You will need to install this with pip/pip3 if you do not already have it
import requests

#########
#
#    CONSTANTS
#

# The basic English Wikipedia API endpoint
API_ENWIKIPEDIA_ENDPOINT = "https://en.wikipedia.org/w/api.php"

# We'll assume that there needs to be some throttling for these requests - we should always be nice to a free data resource
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED

# When making automated requests we should include something that is unique to the person making the request
# This should include an email - your UW email would be good to put in there
REQUEST_HEADERS = {
    'User-Agent': '<shwet695@uw.edu>, University of Washington, MSDS DATA 512 - AUTUMN 2022',
}


# This is a string of additional page properties that can be returned see the Info documentation for
# what can be included. If you don't want any this can simply be the empty string
PAGEINFO_EXTENDED_PROPERTIES = "talkid|url|watched|watchers"
#PAGEINFO_EXTENDED_PROPERTIES = ""

# This template lists the basic parameters for making this
PAGEINFO_PARAMS_TEMPLATE = {
    "action": "query",
    "format": "json",
    "titles": "",           # to simplify this should be a single page title at a time
    "prop": "info",
    "inprop": PAGEINFO_EXTENDED_PROPERTIES
}

# %% [markdown]
# ## Loading Politician csv data

# %%
politician_df = pd.read_csv(r"./data/politicians_by_country_SEPT.2022.csv")
politician_df
# Out:
#                        name  \
# 0           Shahjahan Noori
# 1     Abdul Ghafar Lakanwal
# 2            Majah Ha Adrif
# 3         Haroon al-Afghani
# 4               Tayyab Agha
# ...                     ...
# 7579        Rekayi Tangwena
# 7580       Josiah Tongogara
# 7581      Langton Towungana
# 7582    Herbert Ushewokunze
# 7583           Denis Walker
#
#                                                     url      country
# 0         https://en.wikipedia.org/wiki/Shahjahan_Noori  Afghanistan
# 1     https://en.wikipedia.org/wiki/Abdul_Ghafar_Lak...  Afghanistan
# 2          https://en.wikipedia.org/wiki/Majah_Ha_Adrif  Afghanistan
# 3       https://en.wikipedia.org/wiki/Haroon_al-Afghani  Afghanistan
# 4             https://en.wikipedia.org/wiki/Tayyab_Agha  Afghanistan
# ...                                                 ...          ...
# 7579      https://en.wikipedia.org/wiki/Rekayi_Tangwena     Zimbabwe
# 7580     https://en.wikipedia.org/wiki/Josiah_Tongogara     Zimbabwe
# 7581    https://en.wikipedia.org/wiki/Langton_Towungana     Zimbabwe
# 7582  https://en.wikipedia.org/wiki/Herbert_Ushewokunze     Zimbabwe
# 7583         https://en.wikipedia.org/wiki/Denis_Walker     Zimbabwe
#
# [7584 rows x 3 columns]

# %%
# No null data in politician_df
politician_df.isna().sum()
# Out:
# name       0
# url        0
# country    0
# dtype: int64

# %%
# This is just a list of politicians Wikipedia article titles
ARTICLE_TITLES = list(politician_df.name)

# %%
#########
#
#    PROCEDURES/FUNCTIONS
#

def request_pageinfo_per_article(article_title = None, 
                                 endpoint_url = API_ENWIKIPEDIA_ENDPOINT, 
                                 request_template = PAGEINFO_PARAMS_TEMPLATE,
                                 headers = REQUEST_HEADERS):
    # Make sure we have an article title
    if not article_title: return None
    
    request_template['titles'] = article_title
        
    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free
        # data source like Wikipedia - or any other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(endpoint_url, headers=headers, params=request_template)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response


# Calling API for article names in batches of 25
rev_id_data = []
for i in range(0, len(ARTICLE_TITLES), 25):
    data = request_pageinfo_per_article("|".join(ARTICLE_TITLES[i:i+25]))
    #print(data)
    rev_id_data.extend(list(data['query']['pages'].values()))

# %%
rev_id_data
# Out:
# [{'pageid': 65412901,
#   'ns': 0,
#   'title': 'Abas Basir',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T01:20:40Z',
#   'lastrevid': 1098419766,
#   'length': 19306,
#   'talkid': 65415333,
#   'fullurl': 'https://en.wikipedia.org/wiki/Abas_Basir',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Abas_Basir&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Abas_Basir'},
#  {'pageid': 27428272,
#   'ns': 0,
#   'title': 'Abdul Baqi Turkistani',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T03:06:55Z',
#   'lastrevid': 889226470,
#   'length': 1297,
#   'talkid': 27595416,
#   'fullurl': 'https://en.wikipedia.org/wiki/Abdul_Baqi_Turkistani',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Abdul_Baqi_Turkistani&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Abdul_Baqi_Turkistani'},
#  {'pageid': 42972519,
#   'ns': 0,
#   'title': 'Abdul Ghafar Lakanwal',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-09-26T05:36:04Z',
#   'lastrevid': 943562276,
#   'length': 4165,
#   'talkid': 42972696,
#   'fullurl': 'https://en.wikipedia.org/wiki/Abdul_Ghafar_Lakanwal',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Abdul_Ghafar_Lakanwal&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Abdul_Ghafar_Lakanwal'},
#  {'pageid': 44482763,
#   'ns': 0,
#   'title': 'Abdul Rahim Ayoubi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T14:05:37Z',
#   'lastrevid': 1108886061,
#   'length': 7508,
#   'talkid': 44489967,
#   'fullurl': 'https://en.wikipedia.org/wiki/Abdul_Rahim_Ayoubi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Abdul_Rahim_Ayoubi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Abdul_Rahim_Ayoubi'},
#  {'pageid': 35571947,
#   'ns': 0,
#   'title': 'Ahmad Behzad',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:30:16Z',
#   'lastrevid': 1103948295,
#   'length': 6991,
#   'talkid': 35571968,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ahmad_Behzad',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ahmad_Behzad&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ahmad_Behzad'},
#  {'pageid': 68624823,
#   'ns': 0,
#   'title': 'Ahmadullah Wasiq',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T01:23:12Z',
#   'lastrevid': 1109361754,
#   'length': 5267,
#   'talkid': 68639469,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ahmadullah_Wasiq',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ahmadullah_Wasiq&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ahmadullah_Wasiq'},
#  {'pageid': 38670742,
#   'ns': 0,
#   'title': 'Alhaj Mutalib Baig',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-09-26T05:20:51Z',
#   'lastrevid': 1111494041,
#   'length': 2440,
#   'talkid': 38670751,
#   'fullurl': 'https://en.wikipedia.org/wiki/Alhaj_Mutalib_Baig',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Alhaj_Mutalib_Baig&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Alhaj_Mutalib_Baig'},
#  {'pageid': 12084570,
#   'ns': 0,
#   'title': 'Amir Muhammad Akhundzada',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:24:11Z',
#   'lastrevid': 1069322182,
#   'length': 8655,
#   'talkid': 23510494,
#   'fullurl': 'https://en.wikipedia.org/wiki/Amir_Muhammad_Akhundzada',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Amir_Muhammad_Akhundzada&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Amir_Muhammad_Akhundzada'},
#  {'pageid': 45251307,
#   'ns': 0,
#   'title': 'Atiqullah Atifmal',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T03:26:52Z',
#   'lastrevid': 1112407669,
#   'length': 5942,
#   'talkid': 47297487,
#   'fullurl': 'https://en.wikipedia.org/wiki/Atiqullah_Atifmal',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Atiqullah_Atifmal&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Atiqullah_Atifmal'},
#  {'pageid': 47805901,
#   'ns': 0,
#   'title': 'Aziza Ahmadyar',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-12T22:10:07Z',
#   'lastrevid': 1087211008,
#   'length': 3750,
#   'talkid': 47806200,
#   'fullurl': 'https://en.wikipedia.org/wiki/Aziza_Ahmadyar',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Aziza_Ahmadyar&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Aziza_Ahmadyar'},
#  {'pageid': 27663861,
#   'ns': 0,
#   'title': 'Bashir Ahmad Bezan',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T03:38:06Z',
#   'lastrevid': 1060707209,
#   'length': 2267,
#   'talkid': 28093401,
#   'fullurl': 'https://en.wikipedia.org/wiki/Bashir_Ahmad_Bezan',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Bashir_Ahmad_Bezan&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Bashir_Ahmad_Bezan'},
#  {'pageid': 24963809,
#   'ns': 0,
#   'title': 'Cheragh Ali Cheragh',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-09-26T04:28:28Z',
#   'lastrevid': 1087211968,
#   'length': 4977,
#   'talkid': 25410745,
#   'fullurl': 'https://en.wikipedia.org/wiki/Cheragh_Ali_Cheragh',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Cheragh_Ali_Cheragh&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Cheragh_Ali_Cheragh'},
#  {'pageid': 11966231,
#   'ns': 0,
#   'title': 'Haroon al-Afghani',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T02:53:39Z',
#   'lastrevid': 1095102390,
#   'length': 16718,
#   'talkid': 15250816,
#   'fullurl': 'https://en.wikipedia.org/wiki/Haroon_al-Afghani',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Haroon_al-Afghani&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Haroon_al-Afghani'},
#  {'pageid': 25153929,
#   'ns': 0,
#   'title': 'Ismael Balkhi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T06:29:49Z',
#   'lastrevid': 1112534409,
#   'length': 7501,
#   'talkid': 28093455,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ismael_Balkhi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ismael_Balkhi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ismael_Balkhi'},
#  {'pageid': 10305348,
#   'ns': 0,
#   'title': 'Jan Baz',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:23:59Z',
#   'lastrevid': 997027082,
#   'length': 1771,
#   'talkid': 15014548,
#   'fullurl': 'https://en.wikipedia.org/wiki/Jan_Baz',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Jan_Baz&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Jan_Baz'},
#  {'pageid': 10483286,
#   'ns': 0,
#   'title': 'Majah Ha Adrif',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T00:16:18Z',
#   'lastrevid': 852404094,
#   'length': 3162,
#   'talkid': 13330265,
#   'fullurl': 'https://en.wikipedia.org/wiki/Majah_Ha_Adrif',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Majah_Ha_Adrif&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Majah_Ha_Adrif'},
#  {'pageid': 49752089,
#   'ns': 0,
#   'title': 'Mohammad Asim Asim',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:38:19Z',
#   'lastrevid': 1013838830,
#   'length': 2760,
#   'talkid': 49899838,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammad_Asim_Asim',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammad_Asim_Asim&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammad_Asim_Asim'},
#  {'pageid': 40960242,
#   'ns': 0,
#   'title': 'Mohammad Ghous Bashiri',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T16:28:27Z',
#   'lastrevid': 1102150221,
#   'length': 2677,
#   'talkid': 40960350,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammad_Ghous_Bashiri',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammad_Ghous_Bashiri&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammad_Ghous_Bashiri'},
#  {'pageid': 27664854,
#   'ns': 0,
#   'title': 'Mohammad Sarwar Ahmedzai',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T01:51:12Z',
#   'lastrevid': 1038918070,
#   'length': 4433,
#   'talkid': 60642795,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammad_Sarwar_Ahmedzai',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammad_Sarwar_Ahmedzai&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammad_Sarwar_Ahmedzai'},
#  {'pageid': 14454477,
#   'ns': 0,
#   'title': 'Mohammad Siddiq Chakari',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T13:48:43Z',
#   'lastrevid': 1105913099,
#   'length': 1805,
#   'talkid': 14454495,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammad_Siddiq_Chakari',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammad_Siddiq_Chakari&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammad_Siddiq_Chakari'},
#  {'pageid': 70019038,
#   'ns': 0,
#   'title': 'Muqadasa Ahmadzai',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-09-26T07:51:42Z',
#   'lastrevid': 1082489593,
#   'length': 3789,
#   'talkid': 70021080,
#   'fullurl': 'https://en.wikipedia.org/wiki/Muqadasa_Ahmadzai',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Muqadasa_Ahmadzai&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Muqadasa_Ahmadzai'},
#  {'pageid': 22588409,
#   'ns': 0,
#   'title': 'Nasrullah Baryalai Arsalai',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T08:42:10Z',
#   'lastrevid': 1095526840,
#   'length': 7158,
#   'talkid': 22639116,
#   'fullurl': 'https://en.wikipedia.org/wiki/Nasrullah_Baryalai_Arsalai',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Nasrullah_Baryalai_Arsalai&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Nasrullah_Baryalai_Arsalai'},
#  {'pageid': 16351100,
#   'ns': 0,
#   'title': 'Rafiullah Bidar',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:54:22Z',
#   'lastrevid': 977208323,
#   'length': 3353,
#   'talkid': 28093476,
#   'fullurl': 'https://en.wikipedia.org/wiki/Rafiullah_Bidar',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Rafiullah_Bidar&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Rafiullah_Bidar'},
#  {'pageid': 69537737,
#   'ns': 0,
#   'title': 'Shahjahan Noori',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T05:51:01Z',
#   'lastrevid': 1099689043,
#   'length': 19957,
#   'fullurl': 'https://en.wikipedia.org/wiki/Shahjahan_Noori',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Shahjahan_Noori&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Shahjahan_Noori'},
#  {'pageid': 46841383,
#   'ns': 0,
#   'title': 'Tayyab Agha',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:30:56Z',
#   'lastrevid': 1104998382,
#   'length': 6313,
#   'talkid': 46843786,
#   'fullurl': 'https://en.wikipedia.org/wiki/Tayyab_Agha',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Tayyab_Agha&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Tayyab_Agha'},
#  {'pageid': 29443640,
#   'ns': 0,
#   'title': 'Abdul Ghani Ghani',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:29:32Z',
#   'lastrevid': 1072441893,
#   'length': 1352,
#   'talkid': 29453228,
#   'fullurl': 'https://en.wikipedia.org/wiki/Abdul_Ghani_Ghani',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Abdul_Ghani_Ghani&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Abdul_Ghani_Ghani'},
#  {'pageid': 44098744,
#   'ns': 0,
#   'title': 'Abdul Malik Hamwar',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:30:44Z',
#   'lastrevid': 1100874645,
#   'length': 3512,
#   'talkid': 44237349,
#   'fullurl': 'https://en.wikipedia.org/wiki/Abdul_Malik_Hamwar',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Abdul_Malik_Hamwar&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Abdul_Malik_Hamwar'},
#  {'pageid': 67448458,
#   'ns': 0,
#   'title': 'Abdul Samad Ghaus',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T05:45:16Z',
#   'lastrevid': 1072271854,
#   'length': 2907,
#   'talkid': 67448773,
#   'fullurl': 'https://en.wikipedia.org/wiki/Abdul_Samad_Ghaus',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Abdul_Samad_Ghaus&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Abdul_Samad_Ghaus'},
#  {'pageid': 52438668,
#   'ns': 0,
#   'title': 'Aimal Faizi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:31:12Z',
#   'lastrevid': 1033383351,
#   'length': 2772,
#   'talkid': 52491442,
#   'fullurl': 'https://en.wikipedia.org/wiki/Aimal_Faizi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Aimal_Faizi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Aimal_Faizi'},
#  {'pageid': 37963046,
#   'ns': 0,
#   'title': 'Anarkali Kaur Honaryar',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-12T21:55:40Z',
#   'lastrevid': 1069574154,
#   'length': 4378,
#   'talkid': 37970278,
#   'fullurl': 'https://en.wikipedia.org/wiki/Anarkali_Kaur_Honaryar',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Anarkali_Kaur_Honaryar&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Anarkali_Kaur_Honaryar'},
#  {'pageid': 404323,
#   'ns': 0,
#   'title': 'Ashraf Ghani',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-12T11:35:06Z',
#   'lastrevid': 1113195582,
#   'length': 70032,
#   'watchers': 250,
#   'talkid': 3620441,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ashraf_Ghani',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ashraf_Ghani&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ashraf_Ghani'},
#  {'pageid': 68508979,
#   'ns': 0,
#   'title': 'Elay Ershad',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:32:22Z',
#   'lastrevid': 1102489654,
#   'length': 3181,
#   'talkid': 68520455,
#   'fullurl': 'https://en.wikipedia.org/wiki/Elay_Ershad',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Elay_Ershad&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Elay_Ershad'},
#  {'pageid': 15842120,
#   'ns': 0,
#   'title': 'Ezatullah (Nangarhar)',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-04T14:53:02Z',
#   'lastrevid': 947885788,
#   'length': 1298,
#   'talkid': 18444293,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ezatullah_(Nangarhar)',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ezatullah_(Nangarhar)&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ezatullah_(Nangarhar)'},
#  {'pageid': 68918472,
#   'ns': 0,
#   'title': 'Ghulam Ghaus',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-13T01:54:05Z',
#   'lastrevid': 1115758710,
#   'length': 1445,
#   'talkid': 69064071,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ghulam_Ghaus',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ghulam_Ghaus&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ghulam_Ghaus'},
#  {'pageid': 32550034,
#   'ns': 0,
#   'title': 'Ghulam Haider Hamidi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:30:00Z',
#   'lastrevid': 1095018556,
#   'length': 7653,
#   'talkid': 32550039,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ghulam_Haider_Hamidi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ghulam_Haider_Hamidi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ghulam_Haider_Hamidi'},
#  {'pageid': 25630787,
#   'ns': 0,
#   'title': 'Ghulam Muhammad Ghobar',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:27:24Z',
#   'lastrevid': 1108886395,
#   'length': 3549,
#   'talkid': 27237347,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ghulam_Muhammad_Ghobar',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ghulam_Muhammad_Ghobar&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ghulam_Muhammad_Ghobar'},
#  {'pageid': 13368923,
#   'ns': 0,
#   'title': 'Hashmat Ghani Ahmadzai',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-09T11:25:36Z',
#   'lastrevid': 1112933356,
#   'length': 8351,
#   'watchers': 107,
#   'talkid': 28093454,
#   'fullurl': 'https://en.wikipedia.org/wiki/Hashmat_Ghani_Ahmadzai',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Hashmat_Ghani_Ahmadzai&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Hashmat_Ghani_Ahmadzai'},
#  {'pageid': 35512380,
#   'ns': 0,
#   'title': 'Mahboba Hoqomal',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T15:51:34Z',
#   'lastrevid': 1092518990,
#   'length': 3106,
#   'talkid': 37057619,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mahboba_Hoqomal',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mahboba_Hoqomal&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mahboba_Hoqomal'},
#  {'pageid': 39258771,
#   'ns': 0,
#   'title': 'Mirza Muhammad Ismail',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-09-26T05:22:49Z',
#   'lastrevid': 1073524466,
#   'length': 10699,
#   'talkid': 39258729,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mirza_Muhammad_Ismail',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mirza_Muhammad_Ismail&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mirza_Muhammad_Ismail'},
#  {'pageid': 26027316,
#   'ns': 0,
#   'title': 'Mohammad Gul (Helmand Council)',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T08:37:48Z',
#   'lastrevid': 1092523687,
#   'length': 1300,
#   'talkid': 26033667,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammad_Gul_(Helmand_Council)',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammad_Gul_(Helmand_Council)&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammad_Gul_(Helmand_Council)'},
#  {'pageid': 32365015,
#   'ns': 0,
#   'title': 'Mohammad Nasim Faqiri',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T08:37:48Z',
#   'lastrevid': 1098051193,
#   'length': 13717,
#   'talkid': 32389793,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammad_Nasim_Faqiri',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammad_Nasim_Faqiri&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammad_Nasim_Faqiri'},
#  {'pageid': 32385169,
#   'ns': 0,
#   'title': 'Mohammad Nazar Faqiri',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T08:37:56Z',
#   'lastrevid': 1095525798,
#   'length': 3128,
#   'talkid': 36440135,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammad_Nazar_Faqiri',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammad_Nazar_Faqiri&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammad_Nazar_Faqiri'},
#  {'pageid': 26835722,
#   'ns': 0,
#   'title': 'Muhammad Hashim Esmatullahi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-09-26T04:36:11Z',
#   'lastrevid': 949986748,
#   'length': 2254,
#   'talkid': 26840249,
#   'fullurl': 'https://en.wikipedia.org/wiki/Muhammad_Hashim_Esmatullahi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Muhammad_Hashim_Esmatullahi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Muhammad_Hashim_Esmatullahi'},
#  {'pageid': 8575012,
#   'ns': 0,
#   'title': 'Musa Hotak',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-09-20T00:59:49Z',
#   'lastrevid': 1094201417,
#   'length': 2965,
#   'talkid': 9295688,
#   'fullurl': 'https://en.wikipedia.org/wiki/Musa_Hotak',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Musa_Hotak&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Musa_Hotak'},
#  {'pageid': 59378987,
#   'ns': 0,
#   'title': 'Nasir Ahmad Durrani',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:31:42Z',
#   'lastrevid': 988838315,
#   'length': 2435,
#   'talkid': 59397424,
#   'fullurl': 'https://en.wikipedia.org/wiki/Nasir_Ahmad_Durrani',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Nasir_Ahmad_Durrani&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Nasir_Ahmad_Durrani'},
#  {'pageid': 41835910,
#   'ns': 0,
#   'title': 'Qutbuddin Hilal',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-06T22:35:16Z',
#   'lastrevid': 1104423275,
#   'length': 3278,
#   'talkid': 41837941,
#   'fullurl': 'https://en.wikipedia.org/wiki/Qutbuddin_Hilal',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Qutbuddin_Hilal&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Qutbuddin_Hilal'},
#  {'pageid': 68487239,
#   'ns': 0,
#   'title': 'Rangina Hamidi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T05:48:03Z',
#   'lastrevid': 1104280812,
#   'length': 11643,
#   'talkid': 68503822,
#   'fullurl': 'https://en.wikipedia.org/wiki/Rangina_Hamidi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Rangina_Hamidi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Rangina_Hamidi'},
#  {'pageid': 52438868,
#   'ns': 0,
#   'title': 'Sayed Zafar Hashemi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:31:12Z',
#   'lastrevid': 1112804808,
#   'length': 3051,
#   'talkid': 52492081,
#   'fullurl': 'https://en.wikipedia.org/wiki/Sayed_Zafar_Hashemi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Sayed_Zafar_Hashemi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Sayed_Zafar_Hashemi'},
#  {'pageid': 39576119,
#   'ns': 0,
#   'title': 'Shahnaz Himmeti',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:30:33Z',
#   'lastrevid': 909966254,
#   'length': 1235,
#   'talkid': 39576170,
#   'fullurl': 'https://en.wikipedia.org/wiki/Shahnaz_Himmeti',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Shahnaz_Himmeti&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Shahnaz_Himmeti'},
#  {'pageid': 8054084,
#   'ns': 0,
#   'title': 'Sharif Ghalib',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-09-22T14:36:01Z',
#   'lastrevid': 1041460606,
#   'length': 9995,
#   'watchers': 101,
#   'talkid': 8284074,
#   'fullurl': 'https://en.wikipedia.org/wiki/Sharif_Ghalib',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Sharif_Ghalib&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Sharif_Ghalib'},
#  {'pageid': 69128654,
#   'ns': 0,
#   'title': 'Abdul Karim Misaq',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T01:24:05Z',
#   'lastrevid': 1052669338,
#   'length': 2370,
#   'talkid': 69128772,
#   'fullurl': 'https://en.wikipedia.org/wiki/Abdul_Karim_Misaq',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Abdul_Karim_Misaq&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Abdul_Karim_Misaq'},
#  {'pageid': 68481190,
#   'ns': 0,
#   'title': 'Abdul Sattar Mirzakwal',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T05:48:02Z',
#   'lastrevid': 1044450376,
#   'length': 2022,
#   'talkid': 68481193,
#   'fullurl': 'https://en.wikipedia.org/wiki/Abdul_Sattar_Mirzakwal',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Abdul_Sattar_Mirzakwal&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Abdul_Sattar_Mirzakwal'},
#  {'pageid': 51273009,
#   'ns': 0,
#   'title': 'Ahmad Massoud',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:31:12Z',
#   'lastrevid': 1112608262,
#   'length': 16953,
#   'watchers': 38,
#   'talkid': 51339788,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ahmad_Massoud',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ahmad_Massoud&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ahmad_Massoud'},
#  {'pageid': 34682634,
#   'ns': 0,
#   'title': 'Ahmad Wali Massoud',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:30:11Z',
#   'lastrevid': 1108236868,
#   'length': 3435,
#   'talkid': 34682647,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ahmad_Wali_Massoud',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ahmad_Wali_Massoud&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ahmad_Wali_Massoud'},
#  {'pageid': 430417,
#   'ns': 0,
#   'title': 'Ahmed Wali Karzai',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-08T23:42:26Z',
#   'lastrevid': 1090245979,
#   'length': 22576,
#   'talkid': 7029750,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ahmed_Wali_Karzai',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ahmed_Wali_Karzai&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ahmed_Wali_Karzai'},
#  {'pageid': 35520084,
#   'ns': 0,
#   'title': 'Ali Mohammad (politician)',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:30:16Z',
#   'lastrevid': 1050463798,
#   'length': 2402,
#   'talkid': 37057022,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ali_Mohammad_(politician)',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ali_Mohammad_(politician)&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ali_Mohammad_(politician)'},
#  {'pageid': 42542399,
#   'ns': 0,
#   'title': 'Amin Karim',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-09-26T05:35:03Z',
#   'lastrevid': 1106333491,
#   'length': 8351,
#   'talkid': 42931115,
#   'fullurl': 'https://en.wikipedia.org/wiki/Amin_Karim',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Amin_Karim&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Amin_Karim'},
#  {'pageid': 24850187,
#   'ns': 0,
#   'title': 'Azizullah Lodin',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:27:09Z',
#   'lastrevid': 1102817004,
#   'length': 2990,
#   'talkid': 24850621,
#   'fullurl': 'https://en.wikipedia.org/wiki/Azizullah_Lodin',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Azizullah_Lodin&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Azizullah_Lodin'},
#  {'pageid': 23672202,
#   'ns': 0,
#   'title': 'Baran Khan Kudezai',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T01:41:08Z',
#   'lastrevid': 1106151353,
#   'length': 3754,
#   'talkid': 23992347,
#   'fullurl': 'https://en.wikipedia.org/wiki/Baran_Khan_Kudezai',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Baran_Khan_Kudezai&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Baran_Khan_Kudezai'},
#  {'pageid': 45062095,
#   'ns': 0,
#   'title': 'Faizullah Kakar',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T14:28:52Z',
#   'lastrevid': 1108932917,
#   'length': 20398,
#   'talkid': 47268182,
#   'fullurl': 'https://en.wikipedia.org/wiki/Faizullah_Kakar',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Faizullah_Kakar&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Faizullah_Kakar'},
#  {'pageid': 34369829,
#   'ns': 0,
#   'title': 'Farida Kuchi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T11:23:26Z',
#   'lastrevid': 1109436134,
#   'length': 5182,
#   'talkid': 34372723,
#   'fullurl': 'https://en.wikipedia.org/wiki/Farida_Kuchi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Farida_Kuchi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Farida_Kuchi'},
#  {'pageid': 68717703,
#   'ns': 0,
#   'title': 'Farzana Kochai',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:32:27Z',
#   'lastrevid': 1079430136,
#   'length': 1707,
#   'talkid': 68722018,
#   'fullurl': 'https://en.wikipedia.org/wiki/Farzana_Kochai',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Farzana_Kochai&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Farzana_Kochai'},
#  {'pageid': 273143,
#   'ns': 0,
#   'title': 'Fazel Ahmed Manawi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:17:23Z',
#   'lastrevid': 1106464575,
#   'length': 2256,
#   'talkid': 9295258,
#   'fullurl': 'https://en.wikipedia.org/wiki/Fazel_Ahmed_Manawi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Fazel_Ahmed_Manawi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Fazel_Ahmed_Manawi'},
#  {'pageid': 5294659,
#   'ns': 0,
#   'title': 'Hafizullah Shabaz Khail',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-12T22:37:34Z',
#   'lastrevid': 1092416288,
#   'length': 7500,
#   'talkid': 6598565,
#   'fullurl': 'https://en.wikipedia.org/wiki/Hafizullah_Shabaz_Khail',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Hafizullah_Shabaz_Khail&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Hafizullah_Shabaz_Khail'},
#  {'pageid': 71600382,
#   'ns': 0,
#   'title': 'Khadija Zahra Ahmadi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:21:52Z',
#   'lastrevid': 1115331693,
#   'length': 2616,
#   'talkid': 71610138,
#   'fullurl': 'https://en.wikipedia.org/wiki/Khadija_Zahra_Ahmadi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Khadija_Zahra_Ahmadi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Khadija_Zahra_Ahmadi'},
#  {'pageid': 3056711,
#   'ns': 0,
#   'title': 'Masoud Khalili',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:22:40Z',
#   'lastrevid': 1103105365,
#   'length': 23038,
#   'watchers': 93,
#   'talkid': 7104082,
#   'fullurl': 'https://en.wikipedia.org/wiki/Masoud_Khalili',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Masoud_Khalili&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Masoud_Khalili'},
#  {'pageid': 64024293,
#   'ns': 0,
#   'title': 'Moeen Marastial',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T05:40:00Z',
#   'lastrevid': 1102907176,
#   'length': 7962,
#   'talkid': 64026333,
#   'fullurl': 'https://en.wikipedia.org/wiki/Moeen_Marastial',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Moeen_Marastial&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Moeen_Marastial'},
#  {'pageid': 24781312,
#   'ns': 0,
#   'title': 'Mohammad Daud Miraki',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T06:28:39Z',
#   'lastrevid': 1112192884,
#   'length': 6686,
#   'talkid': 24793110,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammad_Daud_Miraki',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammad_Daud_Miraki&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammad_Daud_Miraki'},
#  {'pageid': 45419022,
#   'ns': 0,
#   'title': 'Mohammad Khan (athlete)',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:30:55Z',
#   'lastrevid': 1070779097,
#   'length': 1071,
#   'talkid': 47327685,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammad_Khan_(athlete)',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammad_Khan_(athlete)&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammad_Khan_(athlete)'},
#  {'pageid': 17013397,
#   'ns': 0,
#   'title': 'Razaq Mamoon',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-09T13:44:50Z',
#   'lastrevid': 1100189662,
#   'length': 4112,
#   'watchers': 43,
#   'talkid': 28093653,
#   'fullurl': 'https://en.wikipedia.org/wiki/Razaq_Mamoon',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Razaq_Mamoon&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Razaq_Mamoon'},
#  {'pageid': 40495241,
#   'ns': 0,
#   'title': 'Rouh Gul Khairzad',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:30:36Z',
#   'lastrevid': 925562571,
#   'length': 1548,
#   'talkid': 57938972,
#   'fullurl': 'https://en.wikipedia.org/wiki/Rouh_Gul_Khairzad',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Rouh_Gul_Khairzad&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Rouh_Gul_Khairzad'},
#  {'pageid': 6392185,
#   'ns': 0,
#   'title': 'Said Tayeb Jawad',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:23:14Z',
#   'lastrevid': 1093621927,
#   'length': 27775,
#   'watchers': 66,
#   'talkid': 7156482,
#   'fullurl': 'https://en.wikipedia.org/wiki/Said_Tayeb_Jawad',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Said_Tayeb_Jawad&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Said_Tayeb_Jawad'},
#  {'pageid': 7493859,
#   'ns': 0,
#   'title': 'Samoud Khan',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:23:23Z',
#   'lastrevid': 1010948755,
#   'length': 4266,
#   'talkid': 9287527,
#   'fullurl': 'https://en.wikipedia.org/wiki/Samoud_Khan',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Samoud_Khan&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Samoud_Khan'},
#  {'pageid': 21500352,
#   'ns': 0,
#   'title': 'Sayed Jalal',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-09-26T04:06:30Z',
#   'lastrevid': 1078580238,
#   'length': 2941,
#   'talkid': 21502485,
#   'fullurl': 'https://en.wikipedia.org/wiki/Sayed_Jalal',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Sayed_Jalal&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Sayed_Jalal'},
#  {'pageid': 27668571,
#   'ns': 0,
#   'title': 'Sayed Jalal Karim',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T21:43:06Z',
#   'lastrevid': 1060701067,
#   'length': 4018,
#   'talkid': 28093484,
#   'fullurl': 'https://en.wikipedia.org/wiki/Sayed_Jalal_Karim',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Sayed_Jalal_Karim&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Sayed_Jalal_Karim'},
#  {'pageid': 27678731,
#   'ns': 0,
#   'title': 'Abdul Majid Samim',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:28:19Z',
#   'lastrevid': 1098092701,
#   'length': 3798,
#   'talkid': 28093433,
#   'fullurl': 'https://en.wikipedia.org/wiki/Abdul_Majid_Samim',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Abdul_Majid_Samim&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Abdul_Majid_Samim'},
#  {'pageid': 68786729,
#   'ns': 0,
#   'title': 'Ali Maisam Nazary',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T05:48:42Z',
#   'lastrevid': 1107279930,
#   'length': 4267,
#   'talkid': 68790580,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ali_Maisam_Nazary',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ali_Maisam_Nazary&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ali_Maisam_Nazary'},
#  {'pageid': 26000816,
#   'ns': 0,
#   'title': 'Amrullah Saleh',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-09T12:53:57Z',
#   'lastrevid': 1115022704,
#   'length': 65066,
#   'watchers': 58,
#   'talkid': 26010226,
#   'fullurl': 'https://en.wikipedia.org/wiki/Amrullah_Saleh',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Amrullah_Saleh&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Amrullah_Saleh'},
#  {'pageid': 66087536,
#   'ns': 0,
#   'title': 'Daoud Naji',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T01:21:15Z',
#   'lastrevid': 1110983467,
#   'length': 4602,
#   'talkid': 66111399,
#   'fullurl': 'https://en.wikipedia.org/wiki/Daoud_Naji',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Daoud_Naji&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Daoud_Naji'},
#  {'pageid': 41428570,
#   'ns': 0,
#   'title': 'Davood Moradian',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-09-26T05:32:00Z',
#   'lastrevid': 1106284627,
#   'length': 2310,
#   'talkid': 41631237,
#   'fullurl': 'https://en.wikipedia.org/wiki/Davood_Moradian',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Davood_Moradian&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Davood_Moradian'},
#  {'pageid': 31141810,
#   'ns': 0,
#   'title': 'Fazal Haq Mujahid',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T08:09:07Z',
#   'lastrevid': 1113267490,
#   'length': 5382,
#   'talkid': 34938829,
#   'fullurl': 'https://en.wikipedia.org/wiki/Fazal_Haq_Mujahid',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Fazal_Haq_Mujahid&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Fazal_Haq_Mujahid'},
#  {'pageid': 2333651,
#   'ns': 0,
#   'title': 'Gholam Rabani Nasher',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:22:09Z',
#   'lastrevid': 916899472,
#   'length': 2436,
#   'talkid': 7102786,
#   'fullurl': 'https://en.wikipedia.org/wiki/Gholam_Rabani_Nasher',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Gholam_Rabani_Nasher&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Gholam_Rabani_Nasher'},
#  {'pageid': 27669652,
#   'ns': 0,
#   'title': 'Ghulam Faroq Nijrabi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:28:19Z',
#   'lastrevid': 1093612575,
#   'length': 1743,
#   'talkid': 28093423,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ghulam_Faroq_Nijrabi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ghulam_Faroq_Nijrabi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ghulam_Faroq_Nijrabi'},
#  {'pageid': 25634863,
#   'ns': 0,
#   'title': 'Ghulam Hassan Safi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:27:24Z',
#   'lastrevid': 987269301,
#   'length': 1652,
#   'talkid': 27237342,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ghulam_Hassan_Safi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ghulam_Hassan_Safi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ghulam_Hassan_Safi'},
#  {'pageid': 27657851,
#   'ns': 0,
#   'title': 'Ghulam Mohammad Rigi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T06:55:59Z',
#   'lastrevid': 918256992,
#   'length': 1535,
#   'talkid': 28093449,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ghulam_Mohammad_Rigi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ghulam_Mohammad_Rigi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ghulam_Mohammad_Rigi'},
#  {'pageid': 36473152,
#   'ns': 0,
#   'title': 'Hanifa Safi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:30:16Z',
#   'lastrevid': 994195074,
#   'length': 1886,
#   'talkid': 37045459,
#   'fullurl': 'https://en.wikipedia.org/wiki/Hanifa_Safi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Hanifa_Safi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Hanifa_Safi'},
#  {'pageid': 29170618,
#   'ns': 0,
#   'title': 'Mohammed Tahir Omar',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T08:37:56Z',
#   'lastrevid': 996093541,
#   'length': 3116,
#   'talkid': 34963842,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammed_Tahir_Omar',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammed_Tahir_Omar&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammed_Tahir_Omar'},
#  {'pageid': 28566318,
#   'ns': 0,
#   'title': 'Mohammed Zia Salehi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-09-26T04:44:34Z',
#   'lastrevid': 889806024,
#   'length': 1173,
#   'talkid': 36784816,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mohammed_Zia_Salehi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mohammed_Zia_Salehi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mohammed_Zia_Salehi'},
#  {'pageid': 25997147,
#   'ns': 0,
#   'title': 'Muhammad Arif Sarwari',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T01:47:48Z',
#   'lastrevid': 1079170926,
#   'length': 4879,
#   'talkid': 26003874,
#   'fullurl': 'https://en.wikipedia.org/wiki/Muhammad_Arif_Sarwari',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Muhammad_Arif_Sarwari&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Muhammad_Arif_Sarwari'},
#  {'pageid': 29611637,
#   'ns': 0,
#   'title': 'Muhammad Yunus Nawandish',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:29:32Z',
#   'lastrevid': 1111494390,
#   'length': 9932,
#   'talkid': 29613506,
#   'fullurl': 'https://en.wikipedia.org/wiki/Muhammad_Yunus_Nawandish',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Muhammad_Yunus_Nawandish&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Muhammad_Yunus_Nawandish'},
#  {'pageid': 43297731,
#   'ns': 0,
#   'title': 'Murad Quenili',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:30:44Z',
#   'lastrevid': 1093963498,
#   'length': 929,
#   'talkid': 46277965,
#   'fullurl': 'https://en.wikipedia.org/wiki/Murad_Quenili',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Murad_Quenili&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Murad_Quenili'},
#  {'pageid': 43750807,
#   'ns': 0,
#   'title': 'Nasrin Oryakhil',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T13:57:14Z',
#   'lastrevid': 1097277701,
#   'length': 3976,
#   'talkid': 43760760,
#   'fullurl': 'https://en.wikipedia.org/wiki/Nasrin_Oryakhil',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Nasrin_Oryakhil&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Nasrin_Oryakhil'},
#  {'pageid': 35507800,
#   'ns': 0,
#   'title': 'Nasruddin Mohseni',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T16:47:24Z',
#   'lastrevid': 1095044526,
#   'length': 3663,
#   'talkid': 35512128,
#   'fullurl': 'https://en.wikipedia.org/wiki/Nasruddin_Mohseni',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Nasruddin_Mohseni&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Nasruddin_Mohseni'},
#  {'pageid': 40438168,
#   'ns': 0,
#   'title': 'Rahmatullah Nabil',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T23:30:33Z',
#   'lastrevid': 1112496538,
#   'length': 10523,
#   'talkid': 40438178,
#   'fullurl': 'https://en.wikipedia.org/wiki/Rahmatullah_Nabil',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Rahmatullah_Nabil&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Rahmatullah_Nabil'},
#  {'pageid': 51559994,
#   'ns': 0,
#   'title': 'Saber Sangar',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T21:25:34Z',
#   'lastrevid': 1019860497,
#   'length': 1777,
#   'talkid': 51595428,
# ...
#   'talkid': 66013565,
#   'fullurl': 'https://en.wikipedia.org/wiki/Jofran_Frejat',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Jofran_Frejat&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Jofran_Frejat'},
#  {'pageid': 38451600,
#   'ns': 0,
#   'title': 'José Carlos da Silva Mayrink Ferrão',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T03:09:17Z',
#   'lastrevid': 1085435249,
#   'length': 2949,
#   'talkid': 43264270,
#   'fullurl': 'https://en.wikipedia.org/wiki/Jos%C3%A9_Carlos_da_Silva_Mayrink_Ferr%C3%A3o',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Jos%C3%A9_Carlos_da_Silva_Mayrink_Ferr%C3%A3o&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Jos%C3%A9_Carlos_da_Silva_Mayrink_Ferr%C3%A3o'},
#  {'pageid': 63683403,
#   'ns': 0,
#   'title': 'Jutahy Júnior',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T05:39:11Z',
#   'lastrevid': 983207788,
#   'length': 3550,
#   'talkid': 63687163,
#   'fullurl': 'https://en.wikipedia.org/wiki/Jutahy_J%C3%BAnior',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Jutahy_J%C3%BAnior&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Jutahy_J%C3%BAnior'},
#  {'pageid': 64096804,
#   'ns': 0,
#   'title': 'Murilo Melo Filho',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T14:16:10Z',
#   'lastrevid': 1102568805,
#   'length': 2986,
#   'talkid': 64096810,
#   'fullurl': 'https://en.wikipedia.org/wiki/Murilo_Melo_Filho',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Murilo_Melo_Filho&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Murilo_Melo_Filho'},
#  {'pageid': 1875713,
#   'ns': 0,
#   'title': 'Paulo Cesar Farias',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-08T23:58:06Z',
#   'lastrevid': 1065573695,
#   'length': 5225,
#   'talkid': 12956065,
#   'fullurl': 'https://en.wikipedia.org/wiki/Paulo_Cesar_Farias',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Paulo_Cesar_Farias&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Paulo_Cesar_Farias'},
#  {'pageid': 69546875,
#   'ns': 0,
#   'title': 'Sandra Meira Starling',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T05:51:01Z',
#   'lastrevid': 1099835037,
#   'length': 2709,
#   'talkid': 69547079,
#   'fullurl': 'https://en.wikipedia.org/wiki/Sandra_Meira_Starling',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Sandra_Meira_Starling&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Sandra_Meira_Starling'},
#  {'pageid': 44402718,
#   'ns': 0,
#   'title': 'Antônio Ricardo dos Santos',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T03:24:13Z',
#   'lastrevid': 1028742803,
#   'length': 4223,
#   'talkid': 44494827,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ant%C3%B4nio_Ricardo_dos_Santos',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ant%C3%B4nio_Ricardo_dos_Santos&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ant%C3%B4nio_Ricardo_dos_Santos'},
#  {'pageid': 51351849,
#   'ns': 0,
#   'title': 'Armando Monteiro (politician)',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-13T18:28:12Z',
#   'lastrevid': 1098295517,
#   'length': 4420,
#   'talkid': 51398555,
#   'fullurl': 'https://en.wikipedia.org/wiki/Armando_Monteiro_(politician)',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Armando_Monteiro_(politician)&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Armando_Monteiro_(politician)'},
#  {'pageid': 68911166,
#   'ns': 0,
#   'title': 'Ary Rigo',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T05:48:56Z',
#   'lastrevid': 1100211750,
#   'length': 3287,
#   'talkid': 68913273,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ary_Rigo',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ary_Rigo&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ary_Rigo'},
#  {'pageid': 34237568,
#   'ns': 0,
#   'title': 'Astrojildo Pereira',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T02:06:15Z',
#   'lastrevid': 1083304045,
#   'length': 823,
#   'talkid': 35754129,
#   'fullurl': 'https://en.wikipedia.org/wiki/Astrojildo_Pereira',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Astrojildo_Pereira&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Astrojildo_Pereira'},
#  {'pageid': 70689457,
#   'ns': 0,
#   'title': 'Carlos Eduardo Moreira Ferreira',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T05:53:16Z',
#   'lastrevid': 1087824575,
#   'length': 2604,
#   'talkid': 70694567,
#   'fullurl': 'https://en.wikipedia.org/wiki/Carlos_Eduardo_Moreira_Ferreira',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Carlos_Eduardo_Moreira_Ferreira&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Carlos_Eduardo_Moreira_Ferreira'},
#  {'pageid': 68911361,
#   'ns': 0,
#   'title': 'Carlos Neder',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T05:48:56Z',
#   'lastrevid': 1102908883,
#   'length': 4574,
#   'talkid': 68913258,
#   'fullurl': 'https://en.wikipedia.org/wiki/Carlos_Neder',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Carlos_Neder&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Carlos_Neder'},
#  {'pageid': 53097586,
#   'ns': 0,
#   'title': 'Claudio Modesto',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-13T00:49:04Z',
#   'lastrevid': 994272220,
#   'length': 5893,
#   'talkid': 53097951,
#   'fullurl': 'https://en.wikipedia.org/wiki/Claudio_Modesto',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Claudio_Modesto&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Claudio_Modesto'},
#  {'pageid': 71090496,
#   'ns': 0,
#   'title': 'Domingos Gomes de Aguiar Neto',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T05:54:13Z',
#   'lastrevid': 1109245420,
#   'length': 5128,
#   'talkid': 71096671,
#   'fullurl': 'https://en.wikipedia.org/wiki/Domingos_Gomes_de_Aguiar_Neto',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Domingos_Gomes_de_Aguiar_Neto&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Domingos_Gomes_de_Aguiar_Neto'},
#  {'pageid': 55822833,
#   'ns': 0,
#   'title': 'Dora Nascimento',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T03:48:36Z',
#   'lastrevid': 1028740301,
#   'length': 2142,
#   'talkid': 55822840,
#   'fullurl': 'https://en.wikipedia.org/wiki/Dora_Nascimento',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Dora_Nascimento&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Dora_Nascimento'},
#  {'pageid': 67132468,
#   'ns': 0,
#   'title': 'Euclides Scalco',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T05:44:54Z',
#   'lastrevid': 1101357504,
#   'length': 2154,
#   'talkid': 67132483,
#   'fullurl': 'https://en.wikipedia.org/wiki/Euclides_Scalco',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Euclides_Scalco&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Euclides_Scalco'},
#  {'pageid': 60493716,
#   'ns': 0,
#   'title': 'Eusébio de Queirós',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-09-26T07:20:16Z',
#   'lastrevid': 1091204382,
#   'length': 8094,
#   'talkid': 60493727,
#   'fullurl': 'https://en.wikipedia.org/wiki/Eus%C3%A9bio_de_Queir%C3%B3s',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Eus%C3%A9bio_de_Queir%C3%B3s&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Eus%C3%A9bio_de_Queir%C3%B3s'},
#  {'pageid': 20129067,
#   'ns': 0,
#   'title': 'Francisco José Pinheiro',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T01:25:08Z',
#   'lastrevid': 1089344947,
#   'length': 3299,
#   'talkid': 23701156,
#   'fullurl': 'https://en.wikipedia.org/wiki/Francisco_Jos%C3%A9_Pinheiro',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Francisco_Jos%C3%A9_Pinheiro&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Francisco_Jos%C3%A9_Pinheiro'},
#  {'pageid': 41102505,
#   'ns': 0,
#   'title': 'Henrique Pizzolato',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-10T13:36:41Z',
#   'lastrevid': 940662779,
#   'length': 4475,
#   'talkid': 41929282,
#   'fullurl': 'https://en.wikipedia.org/wiki/Henrique_Pizzolato',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Henrique_Pizzolato&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Henrique_Pizzolato'},
#  {'pageid': 47681745,
#   'ns': 0,
#   'title': 'Hildebrando Pascoal',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-09-26T05:50:22Z',
#   'lastrevid': 1088472912,
#   'length': 6190,
#   'talkid': 47688176,
#   'fullurl': 'https://en.wikipedia.org/wiki/Hildebrando_Pascoal',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Hildebrando_Pascoal&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Hildebrando_Pascoal'},
#  {'pageid': 67388135,
#   'ns': 0,
#   'title': 'Irondi Pugliesi',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T05:45:10Z',
#   'lastrevid': 1111085644,
#   'length': 1430,
#   'talkid': 67388901,
#   'fullurl': 'https://en.wikipedia.org/wiki/Irondi_Pugliesi',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Irondi_Pugliesi&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Irondi_Pugliesi'},
#  {'pageid': 68178303,
#   'ns': 0,
#   'title': 'Joaquim Alvaro Pereira Leite',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-13T18:28:12Z',
#   'lastrevid': 1114125901,
#   'length': 4322,
#   'talkid': 68183573,
#   'fullurl': 'https://en.wikipedia.org/wiki/Joaquim_Alvaro_Pereira_Leite',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Joaquim_Alvaro_Pereira_Leite&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Joaquim_Alvaro_Pereira_Leite'},
#  {'pageid': 67663798,
#   'ns': 0,
#   'title': 'Jorge Picciani',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T05:46:02Z',
#   'lastrevid': 1099308847,
#   'length': 2974,
#   'talkid': 67663816,
#   'fullurl': 'https://en.wikipedia.org/wiki/Jorge_Picciani',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Jorge_Picciani&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Jorge_Picciani'},
#  {'pageid': 23502995,
#   'ns': 0,
#   'title': 'Manuel Luís Osório, Marquis of Erval',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-04T15:08:33Z',
#   'lastrevid': 1110318599,
#   'length': 22873,
#   'watchers': 64,
#   'talkid': 25882412,
#   'fullurl': 'https://en.wikipedia.org/wiki/Manuel_Lu%C3%ADs_Os%C3%B3rio,_Marquis_of_Erval',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Manuel_Lu%C3%ADs_Os%C3%B3rio,_Marquis_of_Erval&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Manuel_Lu%C3%ADs_Os%C3%B3rio,_Marquis_of_Erval'},
#  {'pageid': 68316618,
#   'ns': 0,
#   'title': 'Marco Antonio Raupp',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T05:47:39Z',
#   'lastrevid': 1098664390,
#   'length': 5434,
#   'talkid': 68316890,
#   'fullurl': 'https://en.wikipedia.org/wiki/Marco_Antonio_Raupp',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Marco_Antonio_Raupp&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Marco_Antonio_Raupp'},
#  {'pageid': 52524856,
#   'ns': 0,
#   'title': 'Mario Pinotti',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-09-26T06:12:55Z',
#   'lastrevid': 1033871516,
#   'length': 5811,
#   'talkid': 53519629,
#   'fullurl': 'https://en.wikipedia.org/wiki/Mario_Pinotti',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Mario_Pinotti&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Mario_Pinotti'},
#  {'pageid': 66181196,
#   'ns': 0,
#   'title': 'Miguel Couto',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T05:43:34Z',
#   'lastrevid': 1035994107,
#   'length': 1930,
#   'fullurl': 'https://en.wikipedia.org/wiki/Miguel_Couto',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Miguel_Couto&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Miguel_Couto'},
#  {'pageid': 59268356,
#   'ns': 0,
#   'title': 'Pedro Soares Muñoz',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T04:06:59Z',
#   'lastrevid': 1096764969,
#   'length': 912,
#   'talkid': 64086149,
#   'fullurl': 'https://en.wikipedia.org/wiki/Pedro_Soares_Mu%C3%B1oz',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Pedro_Soares_Mu%C3%B1oz&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Pedro_Soares_Mu%C3%B1oz'},
#  {'pageid': 66906083,
#   'ns': 0,
#   'title': 'Plínio de Arruda Sampaio Jr.',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T05:44:36Z',
#   'lastrevid': 1100471665,
#   'length': 10732,
#   'talkid': 66910132,
#   'fullurl': 'https://en.wikipedia.org/wiki/Pl%C3%ADnio_de_Arruda_Sampaio_Jr.',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Pl%C3%ADnio_de_Arruda_Sampaio_Jr.&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Pl%C3%ADnio_de_Arruda_Sampaio_Jr.'},
#  {'pageid': 69536525,
#   'ns': 0,
#   'title': 'Ratinho (TV presenter)',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-11T05:51:01Z',
#   'lastrevid': 1114298116,
#   'length': 4941,
#   'talkid': 69536556,
#   'fullurl': 'https://en.wikipedia.org/wiki/Ratinho_(TV_presenter)',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Ratinho_(TV_presenter)&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Ratinho_(TV_presenter)'},
#  {'pageid': 55858857,
#   'ns': 0,
#   'title': 'Robert Rey (plastic surgeon)',
#   'contentmodel': 'wikitext',
#   'pagelanguage': 'en',
#   'pagelanguagehtmlcode': 'en',
#   'pagelanguagedir': 'ltr',
#   'touched': '2022-10-04T15:08:14Z',
#   'lastrevid': 1112518148,
#   'length': 10958,
#   'talkid': 55858869,
#   'fullurl': 'https://en.wikipedia.org/wiki/Robert_Rey_(plastic_surgeon)',
#   'editurl': 'https://en.wikipedia.org/w/index.php?title=Robert_Rey_(plastic_surgeon)&action=edit',
#   'canonicalurl': 'https://en.wikipedia.org/wiki/Robert_Rey_(plastic_surgeon)'},
#  ...]

# %%
# List to dataframe conversion and keeping only title & lastrevid information
rev_id_df = pd.DataFrame.from_dict(rev_id_data)[['title', 'lastrevid']]
rev_id_df.head()
# Out:
#                    title     lastrevid
# 0             Abas Basir  1.098420e+09
# 1  Abdul Baqi Turkistani  8.892265e+08
# 2  Abdul Ghafar Lakanwal  9.435623e+08
# 3     Abdul Rahim Ayoubi  1.108886e+09
# 4           Ahmad Behzad  1.103948e+09

# %%
rev_id_df.shape
# Out:
# (7584, 2)

# %%
# 7 titles with no revid.
rev_id_df.isna().sum()
# Out:
# title        0
# lastrevid    7
# dtype: int64

# %%
# dropping 7 titles with no revid.
rev_id_df.dropna(inplace=True)

# %%
rev_id_df.shape
# Out:
# (7577, 2)

# %% [markdown]
# # Data acquisition - ORES data scores for wikipedia articles on politicians

# %% [markdown]
# ## Calling ORES API for wikipedia article quality prediction

# %%
# These are standard python modules
import json, time, urllib.parse
#
# The 'requests' module is not a standard Python module. You will need to install this with pip/pip3 if you do not already have it
import requests

#########
#
#    CONSTANTS
#

# The current ORES API endpoint
API_ORES_SCORE_ENDPOINT = "https://ores.wikimedia.org/v3"
# A template for mapping to the URL
#API_ORES_SCORE_PARAMS = "/scores/{context}/{revid}/{model}"
API_ORES_SCORE_PARAMS = "/scores/{context}/?models={model}&revids={revid}"

# Use some delays so that we do not hammer the API with our requests
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED

# When making automated requests we should include something that is unique to the person making the request
# This should include an email - your UW email would be good to put in there
REQUEST_HEADERS = {
    'User-Agent': '<shwet695@uw.edu>, University of Washington, MSDS DATA 512 - AUTUMN 2022'
}

# This template lists the basic parameters for making an ORES request
ORES_PARAMS_TEMPLATE = {
    "context": "enwiki",        # which WMF project for the specified revid
    "revid" : "",               # the revision to be scored - this will probably change each call
    "model": "articlequality"   # the AI/ML scoring model to apply to the reviewion
}


#########
#
#    PROCEDURES/FUNCTIONS
#

def request_ores_score_per_article(article_revid = None, 
                                   endpoint_url = API_ORES_SCORE_ENDPOINT, 
                                   endpoint_params = API_ORES_SCORE_PARAMS, 
                                   request_template = ORES_PARAMS_TEMPLATE,
                                   headers = REQUEST_HEADERS,
                                   features=False):
    # Make sure we have an article revision id
    if not article_revid: return None
    
    # set the revision id into the template
    request_template['revid'] = article_revid
    
    # now, create a request URL by combining the endpoint_url with the parameters for the request
    request_url = endpoint_url+endpoint_params.format(**request_template)
    
    # the features used by the ML model can sometimes be returned as well as scores
    if features:
        request_url = request_url+"?features=true"
    
    # make the request
    try:
        # we'll wait first, to make sure we don't exceed the limit in the situation where an exception
        # occurs during the request processing - throttling is always a good practice with a free
        # data source like ORES - or other community sources
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
rev_id_df.lastrevid
# Out:
# 0       1.098420e+09
# 1       8.892265e+08
# 2       9.435623e+08
# 3       1.108886e+09
# 4       1.103948e+09
#             ...
# 7579    9.042468e+08
# 7580    1.112149e+09
# 7581    1.095960e+09
# 7582    1.108127e+09
# 7583    1.073819e+09
# Name: lastrevid, Length: 7577, dtype: float64

# %%
idx = []
all_scores = []
for i in range(0, len(ARTICLE_REVISIONS), 50):
    
    # joining 50 articles name in one string and then passing it through the API call function
    score = request_ores_score_per_article("|".join(ARTICLE_REVISIONS[i:i+50]))
    keys = list((score['enwiki']['scores'].keys()))

    # appending the output to the final list
    idx.extend(keys)
    #print(keys)
    all_scores.extend(list(map(lambda key: score['enwiki']['scores'][key]['articlequality']['score']['prediction'], keys)))

# %%
# Calling ORES API to fecth ORES scores and prediction for article revids in batches of 25

ARTICLE_REVISIONS = rev_id_df.lastrevid.astype(int).astype(str)

id_info = []
ores_data = []
for i in range(0, len(ARTICLE_REVISIONS), 25):
    data = request_ores_score_per_article("|".join(ARTICLE_REVISIONS[i:i+25]))
    #print(data)
    #print(data['enwiki']['scores'])
    keys_info = list((data['enwiki']['scores'].keys()))

    # appending each batch output to the final ores data
    id_info.extend(keys_info)
    #print(keys)
    ores_data.extend(list(map(lambda key: data['enwiki']['scores'][key]['articlequality']['score']['prediction'], keys_info)))

# %% [markdown]
# ### The article quality estimates are, from best to worst:
#
# FA - Featured article
#
# GA - Good article
#
# B - B-class article
#
# C - C-class article
#
# Start - Start-class article
#
# Stub - Stub-class article

# %%
ores_data[:10]
# Out:
# ['Stub',
#  'Start',
#  'Start',
#  'Start',
#  'Start',
#  'Start',
#  'Start',
#  'B',
#  'Start',
#  'C']

# %%
# converting the list to dataframe
ores_df = pd.DataFrame(list(zip(id_info, ores_data)), columns=['lastrevid', 'score'])
ores_df['lastrevid'] = ores_df['lastrevid'].astype(int)
ores_df.head()
# Out:
#     lastrevid  score
# 0  1013838830   Stub
# 1  1038918070  Start
# 2  1060707209  Start
# 3  1069322182  Start
# 4  1082489593  Start

# %% [markdown]
# # Creating 1 dataframe from combining all data so far

# %%
# merging politician and rev id data
df = pd.merge(politician_df, rev_id_df, left_on='name', right_on='title', how='right')
df.head()
# Out:
#                     name                                                url  \
# 0             Abas Basir           https://en.wikipedia.org/wiki/Abas_Basir
# 1  Abdul Baqi Turkistani  https://en.wikipedia.org/wiki/Abdul_Baqi_Turki...
# 2  Abdul Ghafar Lakanwal  https://en.wikipedia.org/wiki/Abdul_Ghafar_Lak...
# 3     Abdul Rahim Ayoubi   https://en.wikipedia.org/wiki/Abdul_Rahim_Ayoubi
# 4           Ahmad Behzad         https://en.wikipedia.org/wiki/Ahmad_Behzad
#
#        country                  title     lastrevid
# 0  Afghanistan             Abas Basir  1.098420e+09
# 1  Afghanistan  Abdul Baqi Turkistani  8.892265e+08
# 2  Afghanistan  Abdul Ghafar Lakanwal  9.435623e+08
# 3  Afghanistan     Abdul Rahim Ayoubi  1.108886e+09
# 4  Afghanistan           Ahmad Behzad  1.103948e+09

# %%
df = pd.merge(df, ores_df, on='lastrevid')
df.head()
# Out:
#                     name                                                url  \
# 0             Abas Basir           https://en.wikipedia.org/wiki/Abas_Basir
# 1  Abdul Baqi Turkistani  https://en.wikipedia.org/wiki/Abdul_Baqi_Turki...
# 2  Abdul Ghafar Lakanwal  https://en.wikipedia.org/wiki/Abdul_Ghafar_Lak...
# 3     Abdul Rahim Ayoubi   https://en.wikipedia.org/wiki/Abdul_Rahim_Ayoubi
# 4           Ahmad Behzad         https://en.wikipedia.org/wiki/Ahmad_Behzad
#
#        country                  title     lastrevid  score
# 0  Afghanistan             Abas Basir  1.098420e+09      C
# 1  Afghanistan  Abdul Baqi Turkistani  8.892265e+08   Stub
# 2  Afghanistan  Abdul Ghafar Lakanwal  9.435623e+08  Start
# 3  Afghanistan     Abdul Rahim Ayoubi  1.108886e+09  Start
# 4  Afghanistan           Ahmad Behzad  1.103948e+09  Start

# %%
df.shape
# Out:
# (7919, 6)

# %%
# No null data
df.isna().sum()
# Out:
# name         0
# url          0
# country      0
# title        0
# lastrevid    0
# score        0
# dtype: int64

# %% [markdown]
# ## Loading population data

# %%
population_df = pd.read_csv(r"./data/population_by_country_2022.csv")
population_df
# Out:
#            Geography  Population (millions)
# 0              WORLD                 7963.0
# 1             AFRICA                 1419.0
# 2    NORTHERN AFRICA                  251.0
# 3            Algeria                   44.9
# 4              Egypt                  103.5
# ..               ...                    ...
# 228            Samoa                    0.2
# 229  Solomon Islands                    0.7
# 230            Tonga                    0.1
# 231           Tuvalu                    0.0
# 232          Vanuatu                    0.3
#
# [233 rows x 2 columns]

# %%
population_df.shape
# Out:
# (233, 2)

# %% [markdown]
# Please note: The population_by_country_2022.csv contains some rows that provide cumulative regional population counts.
#
# These rows are distinguished by having ALL CAPS values in the 'geography' field (e.g. AFRICA, OCEANIA). These rows won't match the country values in politicians_by_country.SEPT.2022.csv, but we will retain some of them so that we can report coverage and quality by region as specified in the analysis section below.

# %%
# Adding continents/region info to each country data row
population_df['region'] = population_df.apply(lambda x: x['Geography'] if x['Geography'].isupper() else None, axis = 1)
population_df['region'] = population_df['region'].fillna(method="ffill")
population_df
# Out:
#            Geography  Population (millions)           region
# 0              WORLD                 7963.0            WORLD
# 1             AFRICA                 1419.0           AFRICA
# 2    NORTHERN AFRICA                  251.0  NORTHERN AFRICA
# 3            Algeria                   44.9  NORTHERN AFRICA
# 4              Egypt                  103.5  NORTHERN AFRICA
# ..               ...                    ...              ...
# 228            Samoa                    0.2          OCEANIA
# 229  Solomon Islands                    0.7          OCEANIA
# 230            Tonga                    0.1          OCEANIA
# 231           Tuvalu                    0.0          OCEANIA
# 232          Vanuatu                    0.3          OCEANIA
#
# [233 rows x 3 columns]

# %%
#drop rows in Geography column which have continent/region info
population_df.drop(population_df[population_df['Geography'].str.isupper()].index, inplace = True)
population_df.reset_index(drop=True, inplace = True)

# %%
population_df
# Out:
#            Geography  Population (millions)           region
# 0            Algeria                   44.9  NORTHERN AFRICA
# 1              Egypt                  103.5  NORTHERN AFRICA
# 2              Libya                    6.8  NORTHERN AFRICA
# 3            Morocco                   36.7  NORTHERN AFRICA
# 4              Sudan                   46.9  NORTHERN AFRICA
# ..               ...                    ...              ...
# 204            Samoa                    0.2          OCEANIA
# 205  Solomon Islands                    0.7          OCEANIA
# 206            Tonga                    0.1          OCEANIA
# 207           Tuvalu                    0.0          OCEANIA
# 208          Vanuatu                    0.3          OCEANIA
#
# [209 rows x 3 columns]

# %%
population_df.isna().sum()
# Out:
# Geography                0
# Population (millions)    0
# region                   0
# dtype: int64

# %% [markdown]
# ### Group by region to sum population

# %%
region_population = population_df.groupby('region')['Population (millions)'].sum().reset_index().rename(columns = {'Population (millions)':'region_population'})
region_population
# Out:
#               region  region_population
# 0          CARIBBEAN               43.5
# 1    CENTRAL AMERICA              177.9
# 2       CENTRAL ASIA               78.0
# 3          EAST ASIA             1673.9
# 4     EASTERN AFRICA              472.8
# 5     EASTERN EUROPE              287.4
# 6      MIDDLE AFRICA              196.1
# 7    NORTHERN AFRICA              251.2
# 8   NORTHERN AMERICA              371.6
# 9    NORTHERN EUROPE              106.5
# 10           OCEANIA               43.5
# 11     SOUTH AMERICA              433.9
# 12        SOUTH ASIA             2008.6
# 13    SOUTHEAST ASIA              675.7
# 14   SOUTHERN AFRICA               69.3
# 15   SOUTHERN EUROPE              150.9
# 16    WESTERN AFRICA              429.8
# 17      WESTERN ASIA              294.3
# 18    WESTERN EUROPE              196.9

# %%
region_population.isna().sum()
# Out:
# region               0
# region_population    0
# dtype: int64

# %%
# merging region_population data with country population dataframe
population_df = population_df.merge(region_population, on = 'region', how='left')
population_df.head()
# Out:
#   Geography  Population (millions)           region  region_population
# 0   Algeria                   44.9  NORTHERN AFRICA              251.2
# 1     Egypt                  103.5  NORTHERN AFRICA              251.2
# 2     Libya                    6.8  NORTHERN AFRICA              251.2
# 3   Morocco                   36.7  NORTHERN AFRICA              251.2
# 4     Sudan                   46.9  NORTHERN AFRICA              251.2

# %%
population_df.isna().sum()
# Out:
# Geography                0
# Population (millions)    0
# region                   0
# region_population        0
# dtype: int64

# %% [markdown]
# ### COMBINING ALL DATAFRAMES

# %%
df_final = pd.merge(df, population_df, left_on='country', right_on='Geography', how='outer')
df_final.head()
# Out:
#                     name                                                url  \
# 0             Abas Basir           https://en.wikipedia.org/wiki/Abas_Basir
# 1  Abdul Baqi Turkistani  https://en.wikipedia.org/wiki/Abdul_Baqi_Turki...
# 2  Abdul Ghafar Lakanwal  https://en.wikipedia.org/wiki/Abdul_Ghafar_Lak...
# 3     Abdul Rahim Ayoubi   https://en.wikipedia.org/wiki/Abdul_Rahim_Ayoubi
# 4           Ahmad Behzad         https://en.wikipedia.org/wiki/Ahmad_Behzad
#
#        country                  title     lastrevid  score    Geography  \
# 0  Afghanistan             Abas Basir  1.098420e+09      C  Afghanistan
# 1  Afghanistan  Abdul Baqi Turkistani  8.892265e+08   Stub  Afghanistan
# 2  Afghanistan  Abdul Ghafar Lakanwal  9.435623e+08  Start  Afghanistan
# 3  Afghanistan     Abdul Rahim Ayoubi  1.108886e+09  Start  Afghanistan
# 4  Afghanistan           Ahmad Behzad  1.103948e+09  Start  Afghanistan
#
#    Population (millions)      region  region_population
# 0                   41.1  SOUTH ASIA             2008.6
# 1                   41.1  SOUTH ASIA             2008.6
# 2                   41.1  SOUTH ASIA             2008.6
# 3                   41.1  SOUTH ASIA             2008.6
# 4                   41.1  SOUTH ASIA             2008.6

# %%
df_final.shape
# Out:
# (7944, 10)

# %%
df_final.isna().sum()
# Out:
# name                     25
# url                      25
# country                  25
# title                    25
# lastrevid                25
# score                    25
# Geography                76
# Population (millions)    76
# region                   76
# region_population        76
# dtype: int64

# %% [markdown]
# ## Identifying all countries for which there are no matches

# %%
df_final[df_final.isna().any(axis=1)]['country'].dropna().unique().tolist()
# Out:
# ['Korean']

# %%
df_final[df_final.isna().any(axis=1)]['Geography'].dropna().unique().tolist()
# Out:
# ['Western Sahara',
#  'Mauritius',
#  'Mayotte',
#  'Reunion',
#  'Sao Tome and Principe',
#  'eSwatini',
#  'Canada',
#  'United States',
#  'Curacao',
#  'Guadeloupe',
#  'Martinique',
#  'Puerto Rico',
#  'French Guiana',
#  'Brunei',
#  'Philippines',
#  'China,  Hong Kong SAR',
#  'China,  Macao SAR',
#  'Ireland',
#  'United Kingdom',
#  'Australia',
#  'French Polynesia',
#  'Guam',
#  'Kiribati',
#  'New Caledonia',
#  'New Zealand']

# %%
no_countrymatches = df_final[df_final.isna().any(axis=1)]['country'].dropna().unique().tolist() + df_final[df_final.isna().any(axis=1)]['Geography'].dropna().unique().tolist()
no_countrymatches
# Out:
# ['Korean',
#  'Western Sahara',
#  'Mauritius',
#  'Mayotte',
#  'Reunion',
#  'Sao Tome and Principe',
#  'eSwatini',
#  'Canada',
#  'United States',
#  'Curacao',
#  'Guadeloupe',
#  'Martinique',
#  'Puerto Rico',
#  'French Guiana',
#  'Brunei',
#  'Philippines',
#  'China,  Hong Kong SAR',
#  'China,  Macao SAR',
#  'Ireland',
#  'United Kingdom',
#  'Australia',
#  'French Polynesia',
#  'Guam',
#  'Kiribati',
#  'New Caledonia',
#  'New Zealand']

# %% [markdown]
# ## Saving output of list of these countries, with each country on a separate line called -
# wp_countries-no_match.txt

# %%
with open(r'./output/wp_countries-no_match.txt', 'w') as fp:
    for i in no_countrymatches:
        fp.write("%s\n" % i)

# %% [markdown]
# ## Final dataframe -
# wp_politicians_by_country.csv

# %%
## dropping rows with null information
df_final.dropna(subset=['name'], inplace = True)
df_final.isna().sum()
# Out:
# name                      0
# url                       0
# country                   0
# title                     0
# lastrevid                 0
# score                     0
# Geography                76
# Population (millions)    76
# region                   76
# region_population        76
# dtype: int64

# %%
df_final = df_final[['country','region','Population (millions)','region_population','title','lastrevid','score']]
df_final.head()
# Out:
#        country      region  Population (millions)  region_population  \
# 0  Afghanistan  SOUTH ASIA                   41.1             2008.6
# 1  Afghanistan  SOUTH ASIA                   41.1             2008.6
# 2  Afghanistan  SOUTH ASIA                   41.1             2008.6
# 3  Afghanistan  SOUTH ASIA                   41.1             2008.6
# 4  Afghanistan  SOUTH ASIA                   41.1             2008.6
#
#                    title     lastrevid  score
# 0             Abas Basir  1.098420e+09      C
# 1  Abdul Baqi Turkistani  8.892265e+08   Stub
# 2  Abdul Ghafar Lakanwal  9.435623e+08  Start
# 3     Abdul Rahim Ayoubi  1.108886e+09  Start
# 4           Ahmad Behzad  1.103948e+09  Start

# %%
df_final.columns = ['country','region','population','region_population','article_title','revision_id','article_quality']
df_final.head()
# Out:
#        country      region  population  region_population  \
# 0  Afghanistan  SOUTH ASIA        41.1             2008.6
# 1  Afghanistan  SOUTH ASIA        41.1             2008.6
# 2  Afghanistan  SOUTH ASIA        41.1             2008.6
# 3  Afghanistan  SOUTH ASIA        41.1             2008.6
# 4  Afghanistan  SOUTH ASIA        41.1             2008.6
#
#            article_title   revision_id article_quality
# 0             Abas Basir  1.098420e+09               C
# 1  Abdul Baqi Turkistani  8.892265e+08            Stub
# 2  Abdul Ghafar Lakanwal  9.435623e+08           Start
# 3     Abdul Rahim Ayoubi  1.108886e+09           Start
# 4           Ahmad Behzad  1.103948e+09           Start

# %%
df_final.isna().sum()
# Out:
# country               0
# region               76
# population           76
# region_population    76
# article_title         0
# revision_id           0
# article_quality       0
# dtype: int64

# %%
## Region & population is null for country name "Korean"
df_final[df_final['region'].isna()]['country'].unique()
# Out:
# array(['Korean'], dtype=object)

# %% [markdown]
# It is difficult to identify population of country name "Korean", it is North Korea/South Korea.
#
# Therefore we will drop rows with Korean country name

# %%
df_final.dropna(inplace = True)

# %%
df_final
# Out:
#           country          region  population  region_population  \
# 0     Afghanistan      SOUTH ASIA        41.1             2008.6
# 1     Afghanistan      SOUTH ASIA        41.1             2008.6
# 2     Afghanistan      SOUTH ASIA        41.1             2008.6
# 3     Afghanistan      SOUTH ASIA        41.1             2008.6
# 4     Afghanistan      SOUTH ASIA        41.1             2008.6
# ...           ...             ...         ...                ...
# 7914     Zimbabwe  EASTERN AFRICA        16.3              472.8
# 7915     Zimbabwe  EASTERN AFRICA        16.3              472.8
# 7916     Zimbabwe  EASTERN AFRICA        16.3              472.8
# 7917     Zimbabwe  EASTERN AFRICA        16.3              472.8
# 7918     Zimbabwe  EASTERN AFRICA        16.3              472.8
#
#                   article_title   revision_id article_quality
# 0                    Abas Basir  1.098420e+09               C
# 1         Abdul Baqi Turkistani  8.892265e+08            Stub
# 2         Abdul Ghafar Lakanwal  9.435623e+08           Start
# 3            Abdul Rahim Ayoubi  1.108886e+09           Start
# 4                  Ahmad Behzad  1.103948e+09           Start
# ...                         ...           ...             ...
# 7914          Langton Towungana  9.042468e+08            Stub
# 7915           Leopold Takawira  1.112149e+09           Start
# 7916         Maxwell Zeb Shumba  1.095960e+09           Start
# 7917  Nkululeko Mkastos Sibanda  1.108127e+09           Start
# 7918            Rekayi Tangwena  1.073819e+09            Stub
#
# [7843 rows x 7 columns]

# %% [markdown]
# ## Handling duplicate article entries

# %%
df_final[df_final.article_title.duplicated()]
# Out:
#        country           region  population  region_population  \
# 195    Albania  SOUTHERN EUROPE         2.8              150.9
# 196    Albania  SOUTHERN EUROPE         2.8              150.9
# 197    Albania  SOUTHERN EUROPE         2.8              150.9
# 204     Kosovo  SOUTHERN EUROPE         1.8              150.9
# 205     Kosovo  SOUTHERN EUROPE         1.8              150.9
# ...        ...              ...         ...                ...
# 6315  Suriname    SOUTH AMERICA         0.6              433.9
# 6932   Ukraine   EASTERN EUROPE        41.0              287.4
# 6933   Ukraine   EASTERN EUROPE        41.0              287.4
# 6934   Ukraine   EASTERN EUROPE        41.0              287.4
# 6935   Ukraine   EASTERN EUROPE        41.0              287.4
#
#                 article_title   revision_id article_quality
# 195               Visar Ymeri  1.036757e+09            Stub
# 196               Visar Ymeri  1.036757e+09            Stub
# 197               Visar Ymeri  1.036757e+09            Stub
# 204               Visar Ymeri  1.036757e+09            Stub
# 205               Visar Ymeri  1.036757e+09            Stub
# ...                       ...           ...             ...
# 6315  Grace Schneiders-Howard  1.095801e+09              GA
# 6932            Sergey Abisov  1.113304e+09           Start
# 6933            Sergey Abisov  1.113304e+09           Start
# 6934            Sergey Abisov  1.113304e+09           Start
# 6935            Sergey Abisov  1.113304e+09           Start
#
# [384 rows x 7 columns]

# %%
#dropping duplicate titles
df_final.drop_duplicates(subset = ['article_title'], inplace = True)

# %%
df_final[df_final.duplicated()]
# Out:
# Empty DataFrame
# Columns: [country, region, population, region_population, article_title, revision_id, article_quality]
# Index: []

# %%
# saving the final dataframe to csv
df_final.to_csv('./output/wp_politicians_by_country.csv')

# %% [markdown]
# # ANALYSIS

# %%
df_final.head()
# Out:
#        country      region  population  region_population  \
# 0  Afghanistan  SOUTH ASIA        41.1             2008.6
# 1  Afghanistan  SOUTH ASIA        41.1             2008.6
# 2  Afghanistan  SOUTH ASIA        41.1             2008.6
# 3  Afghanistan  SOUTH ASIA        41.1             2008.6
# 4  Afghanistan  SOUTH ASIA        41.1             2008.6
#
#            article_title   revision_id article_quality
# 0             Abas Basir  1.098420e+09               C
# 1  Abdul Baqi Turkistani  8.892265e+08            Stub
# 2  Abdul Ghafar Lakanwal  9.435623e+08           Start
# 3     Abdul Rahim Ayoubi  1.108886e+09           Start
# 4           Ahmad Behzad  1.103948e+09           Start

# %% [markdown]
# ## Calculating total-articles-per-population
# (a ratio representing the number of articles per population)
#
# population in millions so we multiply population by 10^6
#
# All of these values are “per capita”.

# %%
#By country
ratio_of_articles_per_population_c = (df_final.groupby('country')['article_title'].count() / (df_final.groupby('country')['population'].mean() * 1000000)).to_frame(name='ratio_of_articles_per_population_country').reset_index()
ratio_of_articles_per_population_c.head()
# Out:
#        country  ratio_of_articles_per_population_country
# 0  Afghanistan                              2.871046e-06
# 1      Albania                              2.964286e-05
# 2      Algeria                              7.572383e-07
# 3      Andorra                              1.000000e-04
# 4       Angola                              1.179775e-06

# %%
#By region
ratio_of_articles_per_population_r = (df_final.groupby('region')['article_title'].count() / (df_final.groupby('region')['region_population'].mean() * 1000000)).to_frame(name='ratio_of_articles_per_population_region').reset_index()
ratio_of_articles_per_population_r.head()
# Out:
#             region  ratio_of_articles_per_population_region
# 0        CARIBBEAN                             4.620690e-06
# 1  CENTRAL AMERICA                             1.079258e-06
# 2     CENTRAL ASIA                             1.320513e-06
# 3        EAST ASIA                             1.469622e-07
# 4   EASTERN AFRICA                             1.366328e-06

# %% [markdown]
# ## High-quality-articles-per-population
# (a ratio representing the number of high quality articles per person)
#
# All of these values are “per capita”.

# %% [markdown]
# ### High quality articles -
#
# FA - Featured article
#
# GA - Good article

# %%
# high quality articles dataframe
high_quality_articles_df = df_final[(df_final['article_quality'] == 'FA') | (df_final['article_quality'] == 'GA')]

# high quality articles by country
high_quality_articles_country = (high_quality_articles_df.groupby('country')['article_title'].count() / (high_quality_articles_df.groupby('country')['population'].mean() * 1000000)).to_frame(name='high_quality_article_ratio_countrywise').reset_index()
high_quality_articles_country.head()
# Out:
#        country  high_quality_article_ratio_countrywise
# 0  Afghanistan                            1.459854e-07
# 1      Albania                            2.142857e-06
# 2      Andorra                            2.000000e-05
# 3      Armenia                            3.333333e-07
# 4   Azerbaijan                            9.803922e-08

# %%
# high quality articles by region
high_quality_articles_region = (high_quality_articles_df.groupby('region')['article_title'].count() / (high_quality_articles_df.groupby('region')['region_population'].mean() * 1000000)).to_frame(name='high_quality_article_ratio_regionwise').reset_index()
high_quality_articles_region.head()
# Out:
#             region  high_quality_article_ratio_regionwise
# 0        CARIBBEAN                           1.839080e-07
# 1  CENTRAL AMERICA                           5.621135e-08
# 2     CENTRAL ASIA                           3.846154e-08
# 3        EAST ASIA                           9.558516e-09
# 4   EASTERN AFRICA                           3.172589e-08

# %% [markdown]
# # RESULTS

# %% [markdown]
# ## Top 10 countries by coverage:
# The 10 countries with the highest total articles per capita (in descending order)

# %%
ratio_of_articles_per_population_c.sort_values(by = ['ratio_of_articles_per_population_country'], ascending = False).replace([np.inf, -np.inf], np.nan).dropna().head(10)
# Out:
#                             country  ratio_of_articles_per_population_country
# 5               Antigua and Barbuda                                  0.000170
# 54   Federated States of Micronesia                                  0.000130
# 3                           Andorra                                  0.000100
# 13                         Barbados                                  0.000093
# 104                Marshall Islands                                  0.000090
# 143                      Seychelles                                  0.000060
# 110                      Montenegro                                  0.000055
# 97                       Luxembourg                                  0.000053
# 18                           Bhutan                                  0.000051
# 64                          Grenada                                  0.000050

# %% [markdown]
# ## Bottom 10 countries by coverage:
# The 10 countries with the lowest total articles per capita (in ascending order)

# %%
ratio_of_articles_per_population_c.sort_values(by = ['ratio_of_articles_per_population_country'], ascending = True).head(10)
# Out:
#           country  ratio_of_articles_per_population_country
# 32          China                              1.392176e-09
# 106        Mexico                              7.843137e-09
# 140  Saudi Arabia                              8.174387e-08
# 134       Romania                              1.052632e-07
# 73          India                              1.248942e-07
# 153     Sri Lanka                              1.339286e-07
# 48          Egypt                              1.352657e-07
# 53       Ethiopia                              1.944895e-07
# 161        Taiwan                              2.155172e-07
# 180       Vietnam                              2.716298e-07

# %% [markdown]
# ## Top 10 countries by high quality:
# The 10 countries with the highest high quality articles per capita (in descending order)

# %%
high_quality_articles_country.sort_values(by = ['high_quality_article_ratio_countrywise'], ascending = False).replace([np.inf, -np.inf], np.nan).dropna().head(10)
# Out:
#                   country  high_quality_article_ratio_countrywise
# 2                 Andorra                            2.000000e-05
# 53             Montenegro                            5.000000e-06
# 1                 Albania                            2.142857e-06
# 9      Bosnia-Herzegovina                            1.470588e-06
# 49              Lithuania                            1.071429e-06
# 19                Croatia                            1.052632e-06
# 74               Slovenia                            9.523810e-07
# 61  Palestinian Territory                            9.259259e-07
# 28                  Gabon                            8.333333e-07
# 25                Estonia                            7.692308e-07

# %% [markdown]
# ## Bottom 10 countries by high quality:
# The 10 countries with the lowest high quality articles per capita (in ascending order).

# %%
high_quality_articles_country.sort_values(by = ['high_quality_article_ratio_countrywise'], ascending = True).head(10)
# Out:
#      country  high_quality_article_ratio_countrywise
# 35     India                            4.233700e-09
# 83  Thailand                            1.497006e-08
# 39     Japan                            1.601281e-08
# 58   Nigeria                            1.830664e-08
# 90   Vietnam                            2.012072e-08
# 17  Colombia                            2.036660e-08
# 86    Uganda                            2.118644e-08
# 60  Pakistan                            2.120441e-08
# 79     Sudan                            2.132196e-08
# 37      Iran                            2.257336e-08

# %% [markdown]
# ## Geographic regions by total coverage:
# A rank ordered list of geographic regions (in descending order) by total articles per capita.

# %%
ratio_of_articles_per_population_r.sort_values(by = ['ratio_of_articles_per_population_region'], ascending = False)
# Out:
#              region  ratio_of_articles_per_population_region
# 14  SOUTHERN EUROPE                             5.805169e-06
# 0         CARIBBEAN                             4.620690e-06
# 17   WESTERN EUROPE                             3.539868e-06
# 5    EASTERN EUROPE                             2.522617e-06
# 8   NORTHERN EUROPE                             2.441315e-06
# 16     WESTERN ASIA                             2.324159e-06
# 9           OCEANIA                             1.977011e-06
# 13  SOUTHERN AFRICA                             1.688312e-06
# 4    EASTERN AFRICA                             1.366328e-06
# 10    SOUTH AMERICA                             1.327495e-06
# 2      CENTRAL ASIA                             1.320513e-06
# 15   WESTERN AFRICA                             1.316892e-06
# 1   CENTRAL AMERICA                             1.079258e-06
# 6     MIDDLE AFRICA                             1.035186e-06
# 7   NORTHERN AFRICA                             9.036624e-07
# 12   SOUTHEAST ASIA                             6.067782e-07
# 11       SOUTH ASIA                             3.206213e-07
# 3         EAST ASIA                             1.469622e-07

# %% [markdown]
# ## Geographic regions by high quality coverage:
# Rank ordered list of geographic regions (in descending order) by high quality articles per capita.

# %%
high_quality_articles_region.sort_values(by = ['high_quality_article_ratio_regionwise'], ascending = False)
# Out:
#              region  high_quality_article_ratio_regionwise
# 14  SOUTHERN EUROPE                           3.048376e-07
# 0         CARIBBEAN                           1.839080e-07
# 5    EASTERN EUROPE                           1.322199e-07
# 17   WESTERN EUROPE                           1.117318e-07
# 16     WESTERN ASIA                           9.514101e-08
# 8   NORTHERN EUROPE                           7.511737e-08
# 13  SOUTHERN AFRICA                           5.772006e-08
# 1   CENTRAL AMERICA                           5.621135e-08
# 9           OCEANIA                           4.597701e-08
# 2      CENTRAL ASIA                           3.846154e-08
# 12   SOUTHEAST ASIA                           3.551872e-08
# 4    EASTERN AFRICA                           3.172589e-08
# 15   WESTERN AFRICA                           3.024663e-08
# 7   NORTHERN AFRICA                           2.786624e-08
# 10    SOUTH AMERICA                           2.765614e-08
# 6     MIDDLE AFRICA                           2.549720e-08
# 11       SOUTH ASIA                           1.145076e-08
# 3         EAST ASIA                           9.558516e-09
